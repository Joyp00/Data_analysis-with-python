# %%
import pandas as pd
import csv
import numpy as np

# %%
data = pd.read_csv('mobile_price_train.csv')
data.head(6)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...

# %%
data['n_cores'].value_counts()
# Out:
# 4    274
# 7    259
# 8    256
# 2    247
# 3    246
# 5    246
# 1    242
# 6    230
# Name: n_cores, dtype: int64

# %%
#calculating p-value for battery_power:

#population mean:
population_mean = data['battery_power'].mean()
print("population mean for battery power: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['battery_power'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of battery power: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['battery_power'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for battery power: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for battery power: ",z)

#calculating p-value:
p_value = 2*(0.36) #probability for z-score(-0.37) = 0.36
print("p-value for battery power: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for battery power:  1238.5185
# Sample mean of battery power:  1226.895
# sample std for battery power:  440.9508294299944
# z-score for battery power:  -0.37278785399933767
# p-value for battery power:  0.72
# Feature is statistically significant

# %%
#calculating p-value for blue:

#population mean:
population_mean = data['blue'].mean()
print("population mean for blue: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['blue'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of blue: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['blue'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for blue: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for blue: ",z)

#calculating p-value:
p_value = 2*(0.06) #probability for z-score( -1.57) = 0.06
print("p-value for blue: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for blue:  0.495
# Sample mean of blue:  0.44
# sample std for blue:  0.496386945839635
# z-score for blue:  -1.5669579263200193
# p-value for blue:  0.12
# Feature is statistically significant

# %%
#calculating p-value for clock_speed:

#population mean:
population_mean = data['clock_speed'].mean()
print("population mean for clock_speed: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['clock_speed'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of clock_speed: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['clock_speed'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for clock_speed: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for clock_speed: ",z)

#calculating p-value:
p_value = 2*(1-0.9) #probability for z-score( 1.26) = 0.9
print("p-value for clock_speed: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for clock_speed:  1.52225
# Sample mean of clock_speed:  1.5965000000000007
# sample std for clock_speed:  0.8336892406646496
# z-score for clock_speed:  1.259526354478184
# p-value for clock_speed:  0.19999999999999996
# Feature is statistically significant

# %%
#calculating p-value for dual_sim:

#population mean:
population_mean = data['dual_sim'].mean()
print("population mean for dual_sim: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['dual_sim'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of dual_sim: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['dual_sim'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for dual_sim: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for dual_sim: ",z)

#calculating p-value:
p_value = 2*(1-0.92) #probability for z-score( 1.44) = 0.92
print("p-value for dual_sim: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for dual_sim:  0.5095
# Sample mean of dual_sim:  0.56
# sample std for dual_sim:  0.4963869458396338
# z-score for dual_sim:  1.4387522778029336
# p-value for dual_sim:  0.15999999999999992
# Feature is statistically significant

# %%
#calculating p-value for fc:

#population mean:
population_mean = data['fc'].mean()
print("population mean for fc: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['fc'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of fc: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['fc'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for fc: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for fc: ",z)

#calculating p-value:
p_value = 2*(0.38) #probability for z-score(-0.3) = 0.38
print("p-value for fc: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for fc:  4.3095
# Sample mean of fc:  4.21
# sample std for fc:  4.549274667460736
# z-score for fc:  -0.3093113952046012
# p-value for fc:  0.76
# Feature is statistically significant

# %%
#calculating p-value for four_g:

#population mean:
population_mean = data['four_g'].mean()
print("population mean for four_g: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['four_g'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of four_g: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['four_g'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for four_g: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for four_g: ",z)

#calculating p-value:
p_value = 2*(1-0.83) #probability for z-score(0.95) = 0.83
print("p-value for four_g: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for four_g:  0.5215
# Sample mean of four_g:  0.555
# sample std for four_g:  0.4969657935914711
# z-score for four_g:  0.9533081542115994
# p-value for four_g:  0.3400000000000001
# Feature is statistically significant

# %%
#calculating p-value for int_memory:

#population mean:
population_mean = data['int_memory'].mean()
print("population mean for int_memory: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['int_memory'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of int_memory: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['int_memory'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for int_memory: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for int_memory: ",z)

#calculating p-value:
p_value = 2*(1-0.85) #probability for z-score(1.03) = 0.85
print("p-value for int_memory: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for int_memory:  32.0465
# Sample mean of int_memory:  33.36
# sample std for int_memory:  17.990842114809407
# z-score for int_memory:  1.032508374162193
# p-value for int_memory:  0.30000000000000004
# Feature is statistically significant

# %%
#calculating p-value for m_dep:

#population mean:
population_mean = data['m_dep'].mean()
print("population mean for m_dep: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['m_dep'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of m_dep: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['m_dep'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for m_dep: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for m_dep: ",z)

#calculating p-value:
p_value = 2*(1-0.97) #probability for z-score(1.9) = 0.97
print("p-value for m_dep: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for m_dep:  0.50175
# Sample mean of m_dep:  0.5394999999999999
# sample std for m_dep:  0.28105115192790103
# z-score for m_dep:  1.899531868607304
# p-value for m_dep:  0.06000000000000005
# Feature is statistically significant

# %%
#calculating p-value for mobile_wt:

#population mean:
population_mean = data['mobile_wt'].mean()
print("population mean for mobile_wt: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['mobile_wt'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of mobile_wt: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['mobile_wt'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for mobile_wt: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for mobile_wt: ",z)

#calculating p-value:
p_value = 2*(1-0.85) #probability for z-score(1.05) = 0.85
print("p-value for mobile_wt: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for mobile_wt:  140.249
# Sample mean of mobile_wt:  142.95
# sample std for mobile_wt:  36.384852617538535
# z-score for mobile_wt:  1.0498299586703486
# p-value for mobile_wt:  0.30000000000000004
# Feature is statistically significant

# %%
#calculating p-value for n_cores:

#population mean:
population_mean = data['n_cores'].mean()
print("population mean for n_cores: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['n_cores'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of n_cores: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['n_cores'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for n_cores: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for n_cores: ",z)

#calculating p-value:
p_value = 2*(0.4) #probability for z-score(-0.23) = 0.4
print("p-value for n_cores: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for n_cores:  4.5205
# Sample mean of n_cores:  4.485
# sample std for n_cores:  2.231540947417278
# z-score for n_cores:  -0.22497719130966448
# p-value for n_cores:  0.8
# Feature is statistically significant

# %%
#calculating p-value for pc:

#population mean:
population_mean = data['pc'].mean()
print("population mean for pc: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['pc'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of pc: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['pc'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for pc: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for pc: ",z)

#calculating p-value:
p_value = 2*(1-0.54) #probability for z-score(0.1) = 0.54
print("p-value for pc: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for pc:  9.9165
# Sample mean of pc:  9.96
# sample std for pc:  6.211956213625463
# z-score for pc:  0.09903207274432518
# p-value for pc:  0.9199999999999999
# Feature is statistically significant

# %%
#calculating p-value for px_height:

#population mean:
population_mean = data['px_height'].mean()
print("population mean for px_height: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['px_height'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of px_height: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['px_height'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for px_height: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for px_height: ",z)

#calculating p-value:
p_value = 2*(1-0.93) #probability for z-score(1.5) = 0.93
print("p-value for px_height: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for px_height:  645.108
# Sample mean of px_height:  690.335
# sample std for px_height:  423.30574384834426
# z-score for px_height:  1.5109796574922683
# p-value for px_height:  0.1399999999999999
# Feature is statistically significant

# %%
#calculating p-value for px_width:

#population mean:
population_mean = data['px_width'].mean()
print("population mean for px_width: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['px_width'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of px_width: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['px_width'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for px_width: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for px_width: ",z)

#calculating p-value:
p_value = 2*(0.44) #probability for z-score( -0.15) = 0.44
print("p-value for px_width: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for px_width:  1251.5155
# Sample mean of px_width:  1246.93
# sample std for px_width:  428.82270823733217
# z-score for px_width:  -0.15122511391520438
# p-value for px_width:  0.88
# Feature is statistically significant

# %%
#calculating p-value for ram:

#population mean:
population_mean = data['ram'].mean()
print("population mean for ram: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['ram'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of ram: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['ram'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for ram: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for ram: ",z)

#calculating p-value:
p_value = 2*(1-0.92) #probability for z-score(1.4) = 0.92
print("p-value for ram: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for ram:  2124.213
# Sample mean of ram:  2230.38
# sample std for ram:  1059.2510352130887
# z-score for ram:  1.4174431393995301
# p-value for ram:  0.15999999999999992
# Feature is statistically significant

# %%
#calculating p-value for sc_h:

#population mean:
population_mean = data['sc_h'].mean()
print("population mean for sc_h: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['sc_h'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of sc_h: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['sc_h'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for sc_h: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for sc_h: ",z)

#calculating p-value:
p_value = 2*(1-0.997) #probability for z-score(2.8) = 0.997
print("p-value for sc_h: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for sc_h:  12.3065
# Sample mean of sc_h:  13.115
# sample std for sc_h:  4.113608513215621
# z-score for sc_h:  2.7795344683513767
# p-value for sc_h:  0.006000000000000005
# Feature is not statistically significant

# %%
#calculating p-value for sc_w:

#population mean:
population_mean = data['sc_w'].mean()
print("population mean for sc_w: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['sc_w'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of sc_w: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['sc_w'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for sc_w: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for sc_w: ",z)

#calculating p-value:
p_value = 2*(1-0.69) #probability for z-score(0.5) = 0.69
print("p-value for sc_w: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for sc_w:  5.767
# Sample mean of sc_w:  5.92
# sample std for sc_w:  4.425336145424436
# z-score for sc_w:  0.4889451737283347
# p-value for sc_w:  0.6200000000000001
# Feature is statistically significant

# %%
#calculating p-value for talk_time:

#population mean:
population_mean = data['talk_time'].mean()
print("population mean for talk_time: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['talk_time'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of talk_time: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['talk_time'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for talk_time: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for talk_time: ",z)

#calculating p-value:
p_value = 2*(0.38) #probability for z-score(-0.3) = 0.38
print("p-value for talk_time: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for talk_time:  11.011
# Sample mean of talk_time:  10.905
# sample std for talk_time:  5.450318798015397
# z-score for talk_time:  -0.2750419620704257
# p-value for talk_time:  0.76
# Feature is statistically significant

# %%
#calculating p-value for three_g:

#population mean:
population_mean = data['three_g'].mean()
print("population mean for three_g: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['three_g'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of three_g: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['three_g'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for three_g: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for three_g: ",z)

#calculating p-value:
p_value = 2*(1-0.98) #probability for z-score(1.95) = 0.98
print("p-value for three_g: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for three_g:  0.7615
# Sample mean of three_g:  0.815
# sample std for three_g:  0.3882975663070778
# z-score for three_g:  1.9485166056159609
# p-value for three_g:  0.040000000000000036
# Feature is not statistically significant

# %%
#calculating p-value for touch_screen:

#population mean:
population_mean = data['touch_screen'].mean()
print("population mean for touch_screen: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['touch_screen'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of touch_screen: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['touch_screen'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for touch_screen: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for touch_screen: ",z)

#calculating p-value:
p_value = 2*(1-0.82) #probability for z-score(0.9) = 0.82
print("p-value for touch_screen: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for touch_screen:  0.503
# Sample mean of touch_screen:  0.535
# sample std for touch_screen:  0.4987734956871716
# z-score for touch_screen:  0.9073223494682786
# p-value for touch_screen:  0.3600000000000001
# Feature is statistically significant

# %%
#calculating p-value for wifi:

#population mean:
population_mean = data['wifi'].mean()
print("population mean for wifi: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['wifi'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of wifi: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['wifi'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for wifi: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for wifi: ",z)

#calculating p-value:
p_value = 2*(0.22) #probability for z-score(-0.76) = 0.22
print("p-value for wifi: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for wifi:  0.507
# Sample mean of wifi:  0.48
# sample std for wifi:  0.4995998398718725
# z-score for wifi:  -0.7642869980476019
# p-value for wifi:  0.44
# Feature is statistically significant

# %%
#calculating p-value for price_range:

#population mean:
population_mean = data['price_range'].mean()
print("population mean for price_range: ",population_mean)

#sample mean:
sample = 200
sum = 0.0
for i in range(sample):
    sum += data['price_range'].iloc[i]
    sample_mean = sum/sample
print("Sample mean of price_range: ",sample_mean)

#calculating sample standard deviation:
deviation_sum = 0
for i in range(sample):
    deviation_sum += abs((data['price_range'].iloc[i]- sample_mean))**2   
sample_std = np.sqrt(deviation_sum/sample)
print("sample std for price_range: ",sample_std)

#calculating z-score:
z = (sample_mean - population_mean)/(sample_std/np.sqrt(sample))
print("z-score for price_range: ",z)

#calculating p-value:
p_value = 2*(1-0.96) #probability for z-score( 1.7) = 0.96
print("p-value for price_range: ",p_value)

#suppose significance level alpha = 0.05
if p_value > 0.05:
    print("Feature is statistically significant")
else:
    print("Feature is not statistically significant")
# Out:
# population mean for price_range:  1.5
# Sample mean of price_range:  1.635
# sample std for price_range:  1.1188275112813417
# z-score for price_range:  1.7064188089343395
# p-value for price_range:  0.08000000000000007
# Feature is statistically significant
